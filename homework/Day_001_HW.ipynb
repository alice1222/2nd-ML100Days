# %% [markdown]
# 作業1
#     1. 我找的資料是有關"肺炎的胸部X光圖像"，由於現今空氣品質不良或者氣溫變化大，兒童如果感冒久而不癒，感染肺炎的機率可能會提高，而肺炎引起 的死亡率也逐步提高。然而，透過X 光片診斷肺炎是一個具挑戰性的工作，需要放射科醫師具備專家級的判斷能力。但如果有足夠的資料量可讓電腦透過胸部透視圖自動診斷是否為肺炎，不但可增加判斷是否為肺炎的機率，也可以讓兒童提早治療。
#     2. 資料來源:提供者:Daniel Kermany,Daniel Kermany Medicine and Dentistry University of California - San Diego Kang Zhang, MichaelGoldbaum。蒐集:從兒童中收集並標記了總共5,232張胸部X射線圖像，其中3,883例描繪了肺炎（2,538例細菌和1,345例病毒）和1,349例正常，共計5,856例患者。然後用來自624名患者的234個正常圖像和390個肺炎圖像（242個細菌和148個病毒）測試該模型。
#     3. 資料型態:共有兩個資料夾，分別是訓練用圖檔以及測試用圖黨，裡面各有兩個資料夾分別為正常情況的肺部x光圖以及感染肺炎的x光圖，訓練用圖檔 中，正常的圖有1342張，感染的圖有3876張，測試用圖檔中，正常的234張，感染的有390張，其圖檔皆為JPEG 圖檔。
#     4. 解決的問題如何評估:通過專業放射科醫生標記是否為肺炎後，再透過AI去計算分辨是否為肺炎，來比較判斷率高低。

# %% [markdown]
# 作業2
#     1. 假設我的車隊平均一天的所得要有10萬元，但由於目前這個行業競爭激烈，所以我首先要先分析普遍載客機率最高的地點以及時間，以提升我業績。
#     2. 透過收集行車紀錄器或者相關紀錄儀器，去紀錄我每一位員工的載客量、地點以及時間。
#     3. 並將其資料製作成CVS檔。
#     4. 透過分析資料，我可以知道載客量普遍最多的場所以及時間甚至載客組群。

# %% [markdown]
# 作業3:
# 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# Hint: 如何取平方

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    mse = MSE = sum((y-y_hat)**2)/len(y)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    mae = MAE = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 230.366
# The Mean absolute error is 11.755
